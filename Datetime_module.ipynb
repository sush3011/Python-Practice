# %% [markdown]
# # datetime
#
# Python has the datetime module to help deal with timestamps in your code. Time values are represented with the time class. Times have attributes for hour, minute, second, and microsecond. They can also include time zone information. The arguments to initialize a time instance are optional, but the default of 0 is unlikely to be what you want.
#
# ## time
# Let's take a look at how we can extract time information from the datetime module. We can create a timestamp by specifying datetime.time(hour,minute,second,microsecond)

# %%
import datetime

t = datetime.time(4, 20, 1)  # Hour, minute, second, microsecond(optional)

# Let's show the different components
print(t)
print('hour:', t.hour)  # Hour
print('minute:', t.minute)  # Minute
print('second:', t.second)  # Second
print('microsecond:', t.microsecond)  # Microsecond
print('tzinfo:', t.tzinfo)  # Timezone info
# Out:
# 04:20:01
# hour: 4
# minute: 20
# second: 1
# microsecond: 0
# tzinfo: None

# %% [markdown]
# Note: A time instance only holds values of time, and not a date associated with the time.
#
# We can also check the min and max values a time of day can have in the module:

# %%
print('Earliest:', datetime.time.min)  # Earliest Time
print('Latest:', datetime.time.max)  # Latest Time
print('Resolution:', datetime.time.resolution)  # The smallest possible difference between non-equal time objects
# Out:
# Earliest: 00:00:00
# Latest: 23:59:59.999999
# Resolution: 0:00:00.000001

# %% [markdown]
# The min and max class attributes reflect the valid range of times in a single day.

# %% [markdown]
# ## Dates
# datetime (as you might suspect) also allows us to work with date timestamps. Calendar date values are represented with the date class. Instances have attributes for year, month, and day. It is easy to create a date representing today’s date using the today() class method.
#
# Let's see some examples:

# %%
today = datetime.date.today()
print(today)
print('ctime:', today.ctime())  # Current Time
print('tuple:', today.timetuple())  # All the seperate aspects of the time object
print('ordinal:', today.toordinal())  # Ordinal number of the date
print('Year:', today.year)  # Year
print('Month:', today.month)  # Month
print('Day:', today.day)  # Day
# Out:
# 2020-06-24
# ctime: Wed Jun 24 00:00:00 2020
# tuple: time.struct_time(tm_year=2020, tm_mon=6, tm_mday=24, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=2, tm_yday=176, tm_isdst=-1)
# ordinal: 737600
# Year: 2020
# Month: 6
# Day: 24

# %% [markdown]
# As with time, the range of date values supported can be determined using the min and max attributes.

# %%
print('Earliest:', datetime.date.min)  # Earliest date
print('Latest:', datetime.date.max)  # Latest date
print('Resolution:', datetime.date.resolution)  # # The smallest possible difference between non-equal date objects
# Out:
# Earliest  : 0001-01-01
# Latest: 9999-12-31
# Resolution: 1 day, 0:00:00

# %% [markdown]
# Another way to create new date instances uses the replace() method of an existing date. For example, you can change the year, leaving the day and month alone.

# %%
d1 = datetime.date(2020, 6, 11)
print('d1:', d1)

d2 = d1.replace(year=1990)  # Replacing the year
print('d2:', d2)
# Out:
# d1: 2020-06-11
# d2: 1990-06-11

# %% [markdown]
# # Arithmetic
# We can perform arithmetic on date objects to check for time differences. For example:

# %%
d1
# Out:
# datetime.date(2020, 6, 11)

# %%
d2
# Out:
# datetime.date(1990, 6, 11)

# %%
d1-d2
# Out:
# datetime.timedelta(days=10958)

# %% [markdown]
# This gives us the difference in days between the two dates. You can use the timedelta method to specify various units of times (days, minutes, hours, etc.)
#
# Great! You should now have a basic understanding of how to use datetime with Python to work with timestamps in your code! If you are still not sure, click this link below:
# https://docs.python.org/3/library/datetime.html
